# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set(palette="Set2")

from sklearn.model_selection import train_test_split
from sklearn.metrics import (accuracy_score, f1_score,average_precision_score, confusion_matrix,
                             average_precision_score, precision_score, recall_score, roc_auc_score, )
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn import tree
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler


from xgboost import XGBClassifier, plot_importance
from imblearn.over_sampling import SMOTE
from urllib.parse import urlparse

import mlflow
import mlflow.sklearn

# %%
dataset = pd.read_csv("../data/Churn Modeling.csv")

# %%
dataset.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
dataset.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
dataset.drop(["RowNumber", "CustomerId", "Surname"], axis=1, inplace=True)

# %%
_, ax = plt.subplots(1, 3, figsize=(18, 6))
plt.subplots_adjust(wspace=0.3)
sns.countplot(x = "NumOfProducts", hue="Exited", data = dataset, ax= ax[0])
sns.countplot(x = "HasCrCard", hue="Exited", data = dataset, ax = ax[1])
sns.countplot(x = "IsActiveMember", hue="Exited", data = dataset, ax = ax[2])
# Out:
# <AxesSubplot:xlabel='IsActiveMember', ylabel='count'>

# %%
_, ax = plt.subplots(1, 3, figsize=(18, 6))
plt.subplots_adjust(wspace=0.3)
sns.swarmplot(x = "NumOfProducts", y = "Age", hue="Exited", data = dataset, ax= ax[0])
sns.swarmplot(x = "HasCrCard", y = "Age", data = dataset, hue="Exited", ax = ax[1])
sns.swarmplot(x = "IsActiveMember", y = "Age", hue="Exited", data = dataset, ax = ax[2])
# Out:
# /Users/yahyamohnd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/categorical.py:3543: UserWarning: 92.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/yahyamohnd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/categorical.py:3543: UserWarning: 91.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/yahyamohnd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/categorical.py:3543: UserWarning: 14.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/yahyamohnd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/categorical.py:3543: UserWarning: 93.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/yahyamohnd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/categorical.py:3543: UserWarning: 92.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/yahyamohnd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/categorical.py:3543: UserWarning: 24.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/yahyamohnd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/categorical.py:3543: UserWarning: 65.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/yahyamohnd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/categorical.py:3543: UserWarning: 83.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/yahyamohnd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/categorical.py:3543: UserWarning: 93.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/yahyamohnd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/categorical.py:3543: UserWarning: 92.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/yahyamohnd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/categorical.py:3543: UserWarning: 24.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/yahyamohnd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/categorical.py:3543: UserWarning: 79.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/yahyamohnd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/categorical.py:3543: UserWarning: 90.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/yahyamohnd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/categorical.py:3543: UserWarning: 80.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/yahyamohnd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/categorical.py:3543: UserWarning: 77.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='IsActiveMember', ylabel='Age'>
# /Users/yahyamohnd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/categorical.py:3543: UserWarning: 93.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/yahyamohnd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/categorical.py:3543: UserWarning: 92.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/yahyamohnd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/categorical.py:3543: UserWarning: 24.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/yahyamohnd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/categorical.py:3543: UserWarning: 79.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/yahyamohnd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/categorical.py:3543: UserWarning: 90.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/yahyamohnd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/categorical.py:3543: UserWarning: 88.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/yahyamohnd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/categorical.py:3543: UserWarning: 86.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/yahyamohnd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/categorical.py:3543: UserWarning: 93.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/yahyamohnd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/categorical.py:3543: UserWarning: 92.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/yahyamohnd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/categorical.py:3543: UserWarning: 24.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/yahyamohnd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/categorical.py:3543: UserWarning: 79.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/yahyamohnd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/categorical.py:3543: UserWarning: 90.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/yahyamohnd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/categorical.py:3543: UserWarning: 88.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/yahyamohnd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/categorical.py:3543: UserWarning: 86.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
encoder = LabelEncoder()
dataset["Geography"] = encoder.fit_transform(dataset["Geography"])
dataset["Gender"] = encoder.fit_transform(dataset["Gender"])

# %%
dataset["Age"].value_counts().plot.bar(figsize=(20,6))
# Out:
# <AxesSubplot:>

# %%
facet = sns.FacetGrid(dataset, hue="Exited",aspect=3)
facet.map(sns.kdeplot,"Age",shade= True)
facet.set(xlim=(0, dataset["Age"].max()))
facet.add_legend()

plt.show()
# Out:
# /Users/yahyamohnd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# /Users/yahyamohnd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)

# %%
_, ax =  plt.subplots(1, 2, figsize=(15, 7))
cmap = sns.cubehelix_palette(light=1, as_cmap=True)
sns.scatterplot(x = "Age", y = "Balance", hue = "Exited", cmap = cmap, sizes = (10, 200), data = dataset, ax=ax[0])
sns.scatterplot(x = "Age", y = "CreditScore", hue = "Exited", cmap = cmap, sizes = (10, 200), data = dataset, ax=ax[1])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='CreditScore'>

# %%
facet = sns.FacetGrid(dataset, hue="Exited",aspect=3)
facet.map(sns.kdeplot,"Balance",shade= True)
facet.set(xlim=(0, dataset["Balance"].max()))
facet.add_legend()

plt.show()
# Out:
# /Users/yahyamohnd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# /Users/yahyamohnd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)

# %%
_, ax = plt.subplots(1, 2, figsize=(15, 6))
sns.scatterplot(x = "Balance", y = "Age", data = dataset, hue="Exited", ax = ax[0])
sns.scatterplot(x = "Balance", y = "CreditScore", data = dataset, hue="Exited", ax = ax[1])
# Out:
# <AxesSubplot:xlabel='Balance', ylabel='CreditScore'>

# %%
facet = sns.FacetGrid(dataset, hue="Exited",aspect=3)
facet.map(sns.kdeplot,"CreditScore",shade= True)
facet.set(xlim=(0, dataset["CreditScore"].max()))
facet.add_legend()

plt.show()
# Out:
# /Users/yahyamohnd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# /Users/yahyamohnd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/seaborn/axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)

# %%
plt.figure(figsize=(12,6))
bplot = dataset.boxplot(patch_artist=True)
plt.xticks(rotation=90)       
plt.show()

# %%
plt.subplots(figsize=(11,8))
sns.heatmap(dataset.corr(), annot=True, cmap="RdYlBu")
plt.show()

# %%
scaler = MinMaxScaler()
df_scaled = pd.DataFrame(data = dataset)
df_scaled[:] = scaler.fit_transform(dataset[:])

# %%
df_scaled.head()
# Out:
#    CreditScore  Geography  Gender       Age  Tenure   Balance  NumOfProducts  \
# 0        0.538        0.0     0.0  0.324324     0.2  0.000000       0.000000
# 1        0.516        1.0     0.0  0.310811     0.1  0.334031       0.000000
# 2        0.304        0.0     0.0  0.324324     0.8  0.636357       0.666667
# 3        0.698        0.0     0.0  0.283784     0.1  0.000000       0.333333
# 4        1.000        1.0     0.0  0.337838     0.2  0.500246       0.000000
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0        1.0             1.0         0.506735     1.0
# 1        0.0             1.0         0.562709     0.0
# 2        1.0             0.0         0.569654     1.0
# 3        0.0             0.0         0.469120     0.0
# 4        1.0             1.0         0.395400     0.0

# %%
X = df_scaled.drop("Exited", axis=1)
y = df_scaled["Exited"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0,stratify=y)

# %%
with mlflow.start_run():
    clf = GaussianNB()
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print("Precision:", precision_score(y_test, y_pred))
    print("Recall:", recall_score(y_test, y_pred))
    print("F1:", f1_score(y_test, y_pred))
    print("Area under precision (AUC) Recall:", average_precision_score(y_test, y_pred))
    mlflow.log_param("alpha", accuracy_score(y_test, y_pred))
    mlflow.log_param("l1_ratio", precision_score(y_test, y_pred))
    mlflow.log_metric("rmse", recall_score(y_test, y_pred))
    mlflow.log_metric("r2", f1_score(y_test, y_pred))

    remote_server_uri="https://dagshub.com/YahyaMohand/bank_customers.mlflow"
    mlflow.set_tracking_uri(remote_server_uri)

    tracking_url_type_store = urlparse(mlflow.get_tracking_uri()).scheme

        # Model registry does not work with file store
    if tracking_url_type_store != "file":
            # Register the model
            # There are other ways to use the Model Registry, which depends on the use case,
            # please refer to the doc for more information:
            # https://mlflow.org/docs/latest/model-registry.html#api-workflow
        mlflow.sklearn.log_model(
            clf, "model", registered_model_name="clf"
        )
    else:
        mlflow.sklearn.log_model(clf, "model")
# Out:
# Accuracy: 0.823
# Precision: 0.6962962962962963
# Recall: 0.23095823095823095
# F1: 0.34686346863468637
# Area under precision (AUC) Recall: 0.3173153608153608
# /Users/yahyamohnd/miniforge3/envs/tensorflow/lib/python3.9/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# /Users/yahyamohnd/Desktop/MLOps_Project/bank_customers/bank_customers/notebook/bank_pre.ipynb Cell 22 line <cell line: 1>()
#      <a href='vscode-notebook-cell:/Users/yahyamohnd/Desktop/MLOps_Project/bank_customers/bank_customers/notebook/bank_pre.ipynb#X35sZmlsZQ%3D%3D?line=17'>18</a> if tracking_url_type_store != "file":
#      <a href='vscode-notebook-cell:/Users/yahyamohnd/Desktop/MLOps_Project/bank_customers/bank_customers/notebook/bank_pre.ipynb#X35sZmlsZQ%3D%3D?line=18'>19</a>         # Register the model
#      <a href='vscode-notebook-cell:/Users/yahyamohnd/Desktop/MLOps_Project/bank_customers/bank_customers/notebook/bank_pre.ipynb#X35sZmlsZQ%3D%3D?line=19'>20</a>         # There are other ways to use the Model Registry, which depends on the use case,
#      <a href='vscode-notebook-cell:/Users/yahyamohnd/Desktop/MLOps_Project/bank_customers/bank_customers/notebook/bank_pre.ipynb#X35sZmlsZQ%3D%3D?line=20'>21</a>         # please refer to the doc for more information:
#      <a href='vscode-notebook-cell:/Users/yahyamohnd/Desktop/MLOps_Project/bank_customers/bank_customers/notebook/bank_pre.ipynb#X35sZmlsZQ%3D%3D?line=21'>22</a>         # https://mlflow.org/docs/latest/model-registry.html#api-workflow
# ---> <a href='vscode-notebook-cell:/Users/yahyamohnd/Desktop/MLOps_Project/bank_customers/bank_customers/notebook/bank_pre.ipynb#X35sZmlsZQ%3D%3D?line=22'>23</a>     mlflow.sklearn.log_model(
#      <a href='vscode-notebook-cell:/Users/yahyamohnd/Desktop/MLOps_Project/bank_customers/bank_customers/notebook/bank_pre.ipynb#X35sZmlsZQ%3D%3D?line=23'>24</a>         clf, "model", registered_model_name="clf"
#      <a href='vscode-notebook-cell:/Users/yahyamohnd/Desktop/MLOps_Project/bank_customers/bank_customers/notebook/bank_pre.ipynb#X35sZmlsZQ%3D%3D?line=24'>25</a>     )
#      <a href='vscode-notebook-cell:/Users/yahyamohnd/Desktop/MLOps_Project/bank_customers/bank_customers/notebook/bank_pre.ipynb#X35sZmlsZQ%3D%3D?line=25'>26</a> else:
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/mlflow/sklearn/__init__.py:407, in log_model(sk_model, artifact_path, conda_env, code_paths, serialization_format, registered_model_name, signature, input_example, await_registration_for, pip_requirements, extra_pip_requirements, pyfunc_predict_fn)
#     335 """
#     336 Log a scikit-learn model as an MLflow artifact for the current run. Produces an MLflow Model
#     337 containing the following flavors:
#    (...)
#     405     mlflow.sklearn.log_model(sk_model, "sk_models")
#     406 """
# --> 407 return Model.log(
#     408     artifact_path=artifact_path,
#     409     flavor=mlflow.sklearn,
#     410     sk_model=sk_model,
#     411     conda_env=conda_env,
#     412     code_paths=code_paths,
#     413     serialization_format=serialization_format,
#     414     registered_model_name=registered_model_name,
#     415     signature=signature,
#     416     input_example=input_example,
#     417     await_registration_for=await_registration_for,
#     418     pip_requirements=pip_requirements,
#     419     extra_pip_requirements=extra_pip_requirements,
#     420     pyfunc_predict_fn=pyfunc_predict_fn,
#     421 )
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/mlflow/models/model.py:374, in Model.log(cls, artifact_path, flavor, registered_model_name, await_registration_for, **kwargs)
#     373 flavor.save_model(path=local_path, mlflow_model=mlflow_model, **kwargs)
# --> 374 mlflow.tracking.fluent.log_artifacts(local_path, mlflow_model.artifact_path)
#     375 try:
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/mlflow/tracking/fluent.py:810, in log_artifacts(local_dir, artifact_path)
#     809 run_id = _get_or_start_run().info.run_id
# --> 810 MlflowClient().log_artifacts(run_id, local_dir, artifact_path)
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/mlflow/tracking/client.py:1182, in MlflowClient.log_artifacts(self, run_id, local_dir, artifact_path)
#    1141 """
#    1142 Write a directory of files to the remote ``artifact_uri``.
#    1143
#    (...)
#    1180     is_dir: True
#    1181 """
# -> 1182 self._tracking_client.log_artifacts(run_id, local_dir, artifact_path)
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/mlflow/tracking/_tracking_service/client.py:469, in TrackingServiceClient.log_artifacts(self, run_id, local_dir, artifact_path)
#     463 """
#     464 Write a directory of files to the remote ``artifact_uri``.
#     465
#     466 :param local_dir: Path to the directory of files to write.
#     467 :param artifact_path: If provided, the directory in ``artifact_uri`` to write to.
#     468 """
# --> 469 self._get_artifact_repo(run_id).log_artifacts(local_dir, artifact_path)
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/mlflow/tracking/_tracking_service/client.py:433, in TrackingServiceClient._get_artifact_repo(self, run_id)
#     432 else:
# --> 433     run = self.get_run(run_id)
#     434     artifact_uri = add_databricks_profile_info_to_artifact_uri(
#     435         run.info.artifact_uri, self.tracking_uri
#     436     )
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/mlflow/tracking/_tracking_service/client.py:72, in TrackingServiceClient.get_run(self, run_id)
#      71 _validate_run_id(run_id)
# ---> 72 return self.store.get_run(run_id)
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/mlflow/store/tracking/rest_store.py:163, in RestStore.get_run(self, run_id)
#     162 req_body = message_to_json(GetRun(run_uuid=run_id, run_id=run_id))
# --> 163 response_proto = self._call_endpoint(GetRun, req_body)
#     164 return Run.from_proto(response_proto.run)
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/mlflow/store/tracking/rest_store.py:57, in RestStore._call_endpoint(self, api, json_body)
#      56 response_proto = api.Response()
# ---> 57 return call_endpoint(self.get_host_creds(), endpoint, method, json_body, response_proto)
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/mlflow/utils/rest_utils.py:280, in call_endpoint(host_creds, endpoint, method, json_body, response_proto)
#     277     response = http_request(
#     278         host_creds=host_creds, endpoint=endpoint, method=method, json=json_body
#     279     )
# --> 280 response = verify_rest_response(response, endpoint)
#     281 js_dict = json.loads(response.text)
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/mlflow/utils/rest_utils.py:212, in verify_rest_response(response, endpoint)
#     208         base_msg = "API request to endpoint %s failed with error code %s != 200" % (
#     209             endpoint,
#     210             response.status_code,
#     211         )
# --> 212         raise MlflowException(
#     213             "%s. Response body: '%s'" % (base_msg, response.text),
#     214             error_code=get_error_code(response.status_code),
#     215         )
#     217 # Skip validation for endpoints (e.g. DBFS file-download API) which may return a non-JSON
#     218 # response
#
# MlflowException: API request to endpoint /api/2.0/mlflow/runs/get failed with error code 401 != 200. Response body: ''
#
# During handling of the above exception, another exception occurred:
#
# MlflowException                           Traceback (most recent call last)
# /Users/yahyamohnd/Desktop/MLOps_Project/bank_customers/bank_customers/notebook/bank_pre.ipynb Cell 22 line <cell line: 1>()
#      <a href='vscode-notebook-cell:/Users/yahyamohnd/Desktop/MLOps_Project/bank_customers/bank_customers/notebook/bank_pre.ipynb#X35sZmlsZQ%3D%3D?line=22'>23</a>     mlflow.sklearn.log_model(
#      <a href='vscode-notebook-cell:/Users/yahyamohnd/Desktop/MLOps_Project/bank_customers/bank_customers/notebook/bank_pre.ipynb#X35sZmlsZQ%3D%3D?line=23'>24</a>         clf, "model", registered_model_name="clf"
#      <a href='vscode-notebook-cell:/Users/yahyamohnd/Desktop/MLOps_Project/bank_customers/bank_customers/notebook/bank_pre.ipynb#X35sZmlsZQ%3D%3D?line=24'>25</a>     )
#      <a href='vscode-notebook-cell:/Users/yahyamohnd/Desktop/MLOps_Project/bank_customers/bank_customers/notebook/bank_pre.ipynb#X35sZmlsZQ%3D%3D?line=25'>26</a> else:
# ---> <a href='vscode-notebook-cell:/Users/yahyamohnd/Desktop/MLOps_Project/bank_customers/bank_customers/notebook/bank_pre.ipynb#X35sZmlsZQ%3D%3D?line=26'>27</a>     mlflow.sklearn.log_model(clf, "model")
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/mlflow/tracking/fluent.py:168, in ActiveRun.__exit__(self, exc_type, exc_val, exc_tb)
#     166 def __exit__(self, exc_type, exc_val, exc_tb):
#     167     status = RunStatus.FINISHED if exc_type is None else RunStatus.FAILED
# --> 168     end_run(RunStatus.to_string(status))
#     169     return exc_type is None
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/mlflow/tracking/fluent.py:393, in end_run(status)
#     391 env.unset_variable(_RUN_ID_ENV_VAR)
#     392 run = _active_run_stack.pop()
# --> 393 MlflowClient().set_terminated(run.info.run_id, status)
#     394 _last_active_run_id = run.info.run_id
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/mlflow/tracking/client.py:1647, in MlflowClient.set_terminated(self, run_id, status, end_time)
#    1604 def set_terminated(
#    1605     self, run_id: str, status: Optional[str] = None, end_time: Optional[int] = None
#    1606 ) -> None:
#    1607     """Set a run's status to terminated.
#    1608
#    1609     :param status: A string value of :py:class:`mlflow.entities.RunStatus`.
#    (...)
#    1645         status: KILLED
#    1646     """
# -> 1647     self._tracking_client.set_terminated(run_id, status, end_time)
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/mlflow/tracking/_tracking_service/client.py:506, in TrackingServiceClient.set_terminated(self, run_id, status, end_time)
#     504 end_time = end_time if end_time else get_current_time_millis()
#     505 status = status if status else RunStatus.to_string(RunStatus.FINISHED)
# --> 506 self.store.update_run_info(
#     507     run_id,
#     508     run_status=RunStatus.from_string(status),
#     509     end_time=end_time,
#     510     run_name=None,
#     511 )
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/mlflow/store/tracking/rest_store.py:177, in RestStore.update_run_info(self, run_id, run_status, end_time, run_name)
#     167 """Updates the metadata of the specified run."""
#     168 req_body = message_to_json(
#     169     UpdateRun(
#     170         run_uuid=run_id,
#    (...)
#     175     )
#     176 )
# --> 177 response_proto = self._call_endpoint(UpdateRun, req_body)
#     178 return RunInfo.from_proto(response_proto.run_info)
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/mlflow/store/tracking/rest_store.py:57, in RestStore._call_endpoint(self, api, json_body)
#      55 endpoint, method = _METHOD_TO_INFO[api]
#      56 response_proto = api.Response()
# ---> 57 return call_endpoint(self.get_host_creds(), endpoint, method, json_body, response_proto)
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/mlflow/utils/rest_utils.py:280, in call_endpoint(host_creds, endpoint, method, json_body, response_proto)
#     276 else:
#     277     response = http_request(
#     278         host_creds=host_creds, endpoint=endpoint, method=method, json=json_body
#     279     )
# --> 280 response = verify_rest_response(response, endpoint)
#     281 js_dict = json.loads(response.text)
#     282 parse_dict(js_dict=js_dict, message=response_proto)
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/mlflow/utils/rest_utils.py:212, in verify_rest_response(response, endpoint)
#     207     else:
#     208         base_msg = "API request to endpoint %s failed with error code %s != 200" % (
#     209             endpoint,
#     210             response.status_code,
#     211         )
# --> 212         raise MlflowException(
#     213             "%s. Response body: '%s'" % (base_msg, response.text),
#     214             error_code=get_error_code(response.status_code),
#     215         )
#     217 # Skip validation for endpoints (e.g. DBFS file-download API) which may return a non-JSON
#     218 # response
#     219 if endpoint.startswith(_REST_API_PATH_PREFIX) and not _can_parse_as_json_object(response.text):
#
# MlflowException: API request to endpoint /api/2.0/mlflow/runs/update failed with error code 401 != 200. Response body: ''
